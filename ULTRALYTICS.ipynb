# %% [markdown]
# # **DATA-FORMAT**

# %%
# FOR CLASSIFICATION
# dataset/
#     TRAIN/
#         CLASS_A/
  #         img1.jpg
  #         img2.jpg
  #         ...
#         CLASS_B/
  #         img1.jpg
  #         img2.jpg
  #         ...
#     VAL/
#         CLASS_A/
  #         img1.jpg
  #         img2.jpg
  #         ...
#         CLASS_B/
  #         img1.jpg
  #         img2.jpg
  #         ...

# %%
# FOR OBJ DET N SEG
# dataset/
#     images/
#         train/
  #         img1.jpg
  #         img2.jpg
  #         ...
#         val/
  #         img1.jpg
  #         img2.jpg
  #         ...
#     labels/
#         train/
  #         img1.txt
  #         img2.txt
  #         ...
#         val/
  #         img1.txt
  #         img2.txt
  #         ...

# %%
# FOR OBJ DET N SEG
# dataset/
#     TRAIN/
#         IMAGES/
  #         img1.jpg
  #         img2.jpg
  #         ...
#         LABELS/
  #         img1.txt
  #         img2.txt
  #         ...

#     VAL/
#         LABELS/
  #         img1.txt
  #         img2.txt
  #         ...
#         IMAGES/
  #         img1.jpg
  #         img2.jpg
  #         ...

# %% [markdown]
# # **UNZIP FILE**

# %%
# !unzip /content/objdet.zip
# Out:
# Archive:  /content/objdet.zip
# replace objdet/labels/train/Abyssinian_51.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !unzip /content/objdet12.zip
# Out:
# Archive:  /content/objdet12.zip
#    creating: objdet12/
#    creating: objdet12/val/
#    creating: objdet12/val/labels/
#   inflating: objdet12/val/labels/Abyssinian_105.txt
#   inflating: objdet12/val/labels/Abyssinian_107.txt
#   inflating: objdet12/val/labels/Abyssinian_89.txt
#   inflating: objdet12/val/labels/Abyssinian_88.txt
#   inflating: objdet12/val/labels/Abyssinian_102.txt
#    creating: objdet12/val/images/
#   inflating: objdet12/val/images/Abyssinian_105.jpg
#   inflating: objdet12/val/images/Abyssinian_107.jpg
#   inflating: objdet12/val/images/Abyssinian_89.jpg
#   inflating: objdet12/val/images/Abyssinian_88.jpg
#   inflating: objdet12/val/images/Abyssinian_102.jpg
#    creating: objdet12/train/
#    creating: objdet12/train/labels/
#   inflating: objdet12/train/labels/Abyssinian_51.txt
#   inflating: objdet12/train/labels/Abyssinian_44.txt
#   inflating: objdet12/train/labels/Abyssinian_77.txt
#   inflating: objdet12/train/labels/Abyssinian_10.txt
# ...

# %%
# !unzip /content/final_data.zip
# Out:
# Archive:  /content/final_data.zip
#    creating: final_data/
#    creating: final_data/images/
#    creating: final_data/images/val/
#   inflating: final_data/images/val/Abyssinian_80.jpg
#   inflating: final_data/images/val/Abyssinian_81.jpg
#   inflating: final_data/images/val/Abyssinian_82.jpg
#   inflating: final_data/images/val/Abyssinian_83.jpg
#   inflating: final_data/images/val/Abyssinian_84.jpg
#   inflating: final_data/images/val/Abyssinian_85.jpg
#   inflating: final_data/images/val/Abyssinian_86.jpg
#   inflating: final_data/images/val/Abyssinian_87.jpg
#   inflating: final_data/images/val/Abyssinian_88.jpg
#   inflating: final_data/images/val/Abyssinian_89.jpg
#   inflating: final_data/images/val/Abyssinian_90.jpg
#   inflating: final_data/images/val/Abyssinian_91.jpg
#   inflating: final_data/images/val/Abyssinian_92.jpg
#   inflating: final_data/images/val/Abyssinian_93.jpg
#   inflating: final_data/images/val/Abyssinian_94.jpg
# ...

# %%
# !unzip /content/CLASSIFICATION_DATA.zip
# Out:
# Archive:  /content/CLASSIFICATION_DATA.zip
#    creating: CLASSIFICATION_DATA/
#    creating: CLASSIFICATION_DATA/train/
#    creating: CLASSIFICATION_DATA/train/a/
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_1.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_2.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_3.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_4.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_5.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_6.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_7.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_8.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_9.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_10.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_11.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_12.jpg
#   inflating: CLASSIFICATION_DATA/train/a/Abyssinian_13.jpg
# ...

# %% [markdown]
# # **YAML FILE**

# %%
# path: /content/objdet
# train: images/train
# val: images/val
# # Classes
# nc: 1
# names: ['cat']

# %%
# path: /content/objdet12
# train: train/images
# val: val/images
# # Classes
# nc: 1
# names: ['cat']

# %% [markdown]
# # **INSTALLATION**

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
use_google_colab = True
if use_google_colab:
    from google.colab import drive
    from google.colab import files
    # Mount your Google Drive on your runtime
    # drive.mount('/content/gdrive')

# %% [markdown]
# # **TRAINING CODE FOR CLASSIFICATION**

# %%
# !yolo classify train data=/content/CLASSIFICATION_DATA model=yolov8n-cls.pt epochs=2 imgsz=64
# Out:
# New https://pypi.org/project/ultralytics/8.2.79 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.78 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %% [markdown]
# # **TRAINING CODE FOR OBJ DET**

# %%
# !yolo train model=yolov8x.pt data=/content/data.yaml epochs=1 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.2.79 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.78 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo train model=rtdetr-l.pt data=/content/data.yaml epochs=1 imgsz=640
# Out:
# ...
# 100% 63.4M/63.4M [00:00<00:00, 75.1MB/s]
# New https://pypi.org/project/ultralytics/8.2.79 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.78 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %% [markdown]
# # **TRAINING CODE FOR SEGMENTATION**

# %%
# !yolo segment train data=/content/seg_data.yaml model=yolov8n-seg.pt epochs=1 imgsz=640

# %% [markdown]
# # **SAVE MODEL ON DRIVE**

# %%
# !cp /content/runs/detect/train/weights/best.pt DRIVE_LOCATION

# %%
# !cp /content/runs/detect/train2/weights/best.pt DRIVE_LOCATION

# %% [markdown]
# # **DOWNLOAD FILE**

# %%
use_google_colab = True
if use_google_colab:
    from google.colab import drive
    from google.colab import files
    # Mount your Google Drive on your runtime
    # drive.mount('/content/gdrive')

# %%
if use_google_colab:
    files.download('/content/seg_data.yaml')
